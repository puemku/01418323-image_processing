# %%
# image to pixel array
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

image = Image.open('image/3.png').convert('L')
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
# show the image
image.show()
# Out:
# None
# L
# (1172, 1572)
# <PIL.Image.Image image mode=L size=1172x1572>
